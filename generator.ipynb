# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def Image(infile):
    figure(); axis("off")
    imshow(imread(infile))

# %% [markdown]
# # Noodle Generator

# %% [markdown]
# * We want to automatically generate noodle designs with variable flexibilities.
# * This means we need to try different crossover/kink motifs of the scaffold and staple strands.
# * The first step is to define locations where crossovers can happen

# %% [markdown]
# ## Pre-Crossovers

# %% [markdown]
# Here is our cross section:

# %%
#Image("cadnano2001.png")

# %%
import networkx as nx
G=nx.Graph()
G.add_nodes_from(range(6))
G.add_edge(0,1,label="0 + 21n",start_idx=0)
G.add_edge(1,2,label="14 + 21n",start_idx=14)
G.add_edge(2,3,label="7 + 21n",start_idx=7)
G.add_edge(3,4,label="0 + 21n",start_idx=0)
G.add_edge(4,5,label="14 +21n",start_idx=14)
G.add_edge(0,5,label="7 + 21n",start_idx=7)

# %%
nx.draw_circular(G,node_color="lightyellow",node_size=1000)
pos=nx.circular_layout(G)
edge_labels=dict([((u,v,),d['label'])
             for u,v,d in G.edges(data=True)])
nx.draw_networkx_edge_labels(G,pos,edge_labels=edge_labels);
title("Crossover Locations for Staples");

# %% [markdown]
# #### Initialize our helices:

# %%
length = 84
length +=1
helices = {}
for i in range(6):
    helices[i]= -np.ones(length)

# %%
def plot_helices(helices):
    figure()
    hold(True)
    for i,data in helices.iteritems():
        plot([0,length],[i,i])
    
    axis([-2,length,-1,6])
    yticks(range(6))
    xticks(range(0,length,7))
plot_helices(helices)

# %% [markdown]
# #### Define crossover locations for each Edge on helices

# %%
for u,v,d in G.edges(data=True):
    N = (length-d["start_idx"])/21
    idx = [d["start_idx"]+21*n for n in range(N+1)]
    helices[u][idx] = v 
    helices[v][idx] = u

# %%
def plot_helices(helices):
    figure()
    hold(True)
    for i,data in helices.iteritems():
        plot([0,length],[i,i])
        idx = np.nonzero(data !=-1)[0]
        y = data[idx]
        plot(idx,y,'o',color="grey",alpha=0.5)
        
        for ii,d in enumerate(y):
            annotate('%d'%d,[idx[ii],i])
        
        
    axis([-2,length,-1,6])
    yticks(range(6))
    xticks(range(0,length,7))
    
plot_helices(helices)

# %% [markdown]
# ## Crossovers

# %% [markdown]
# * We need to define a new scheme for when crossovers actually happen!
# * Lets make it similar to the helices structure:

# %%
Xs = {}
for i in range(6):
    Xs[i]= zeros(length).astype(bool)

# %% [markdown]
# * In this case, Xs is a boolean, and the index of a True matches to the index of helices.
# * Now we can easily validate if a structure is valid if there is not a -1 in helices[Xs]

# %%
def validateX(helices,Xs):
    for helix, data in helices.iteritems():
        if -1 in data[Xs[helix]]:
            raise Exception("Invalid!")
        #TODO: add in part for reciprocity
    return True

# %%
validateX(helices,Xs)
# Out:
# True

# %%
Xs[0][2] = True
validateX(helices,Xs)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-62-9788b29d0d9e> in <module>()
#       1 Xs[0][2] = True
# ----> 2 validateX(helices,Xs)
#
# <ipython-input-60-4c9d49e43d3a> in validateX(helices, Xs)
#       2     for helix, data in helices.iteritems():
#       3         if -1 in data[Xs[helix]]:
# ----> 4             raise Exception("Invalid!")
#       5     return True
#
# Exception: Invalid!

# %% [markdown]
# * Great! This works. Now we should plot a crossover

# %%
Xs[0][2] = False
Xs[0][0] = True

# %%
validateX(helices,Xs)
# Out:
# True

# %%
def plot_Xhelices(helices,Xs):
    figure()
    hold(True)
    for i,data in helices.iteritems():
        plot([0,length],[i,i],color="b")
        idx = np.nonzero(data !=-1)[0]
        y = data[idx]
        plot(idx,y,'o',color="grey",alpha=0.5)
        
        for ii,d in enumerate(y):
            annotate('%d'%d,[idx[ii],i])
        
        Xdata = Xs[i]
        Xidx = np.nonzero(Xdata)[0] # <-- list of indices where crossovers happen!
        for Xi in Xidx:
            plot([Xi,Xi],[i,data[Xi]])
        
        
    axis([-2,length,-1,6])
    yticks(range(6))
    xticks(range(0,length,7))
    
plot_Xhelices(helices,Xs)

# %% [markdown]
# * Neat! See the crossover at 0? Now lets generate a random set of crossovers for fun.

# %%
for helix, data in helices.iteritems():
    idx = np.nonzero(data !=-1)[0]
    Xs[helix][idx] = np.random.random_integers(0,1,len(idx)).astype(bool) 
    # Issue: If there is a crossover on helix3 for helix 4, 
    # there needs to be a crossover on helix4 to helix 3!
for helix,data in helices.iteritems():
    neighbors = np.unique(data)[1:].astype(int)
    for n in neighbors:
        idx = np.nonzero(data.astype(int)==n)[0]
        #print n, np.nonzero(data.astype(int)==n)
        Xs[n][idx] += Xs[helix][idx]

# %%
plot_Xhelices(helices,Xs)

# %% [markdown]
# Next Steps:
# -----------
#
# * **Refine**: We know that if a crossover happens at location *n*, it happens at *n-1* also, unless n is 0. We need to account for this "double" crossover in the pre-structure, the validation step, and the plotting.
#
# * **Kinks**: We need a structure that accounts for kinks, and at the least validates across a helix (a kink cannot be too short along a helix, and should not be too close to a crossover)
#
# * **Format**: Need to convert our random structure to cadnano format. Why the random structure, and not something we actually care about? Well, we need to write the program such that *any* structure converts, and testing multiple random structures will account for all the possibilities.  I think this will be hard because of the arrow directions.

# %% [markdown]
# Refine
# ------
#
# Account for two crossovers at each location except 0

# %%
helices = {}
for i in range(6):
    helices[i]= -np.ones(length)
    
for u,v,d in G.edges(data=True):
    N = (length-d["start_idx"])/21
    idx = np.asarray([d["start_idx"]+21*n for n in range(N+1)])
    helices[u][idx] = v 
    helices[v][idx] = u 
    
    helices[u][idx[np.nonzero(idx)]-1] = v 
    helices[v][idx[np.nonzero(idx)]-1] = u

# %%
plot_helices(helices)

# %%
for helix, data in helices.iteritems():
    idx = np.nonzero(data !=-1)[0]
    Xs[helix][idx] = np.random.random_integers(0,1,len(idx)).astype(bool)

# %%
plot_Xhelices(helices,Xs)

# %%
validateX(helices,Xs)
# Out:
# True

# %% [markdown]
# Cool! This works. On the the next step: Kinks

# %% [markdown]
# Kinks
# -----
#
# We need a structure that accounts for kinks, and at the least validates across a helix (a kink cannot be too short along a helix, and should not be too close to a crossover)
#
# * Lets define our structure similar to the crossover structues Xs, a boolean.

# %%
Ks  = {}
for i in range(6):
    Ks[i]= zeros(length).astype(bool)

# %% [markdown]
# Lets randomly place kinks and visualize:

# %%
for helix, data in Xs.iteritems():
    idx = np.nonzero(data==0)[0]
    Ks[helix][idx] = np.random.random_integers(0,1,len(idx)).astype(bool)

# %% [markdown]
# Lets validate kinks: For now there can't be a kink and crossover in the same location

# %%
def validateK(Xs,Ks):
    for helix, data in Xs.iteritems():
        if -1 in data[Ks[helix]]:
            raise Exception("Invalid!")
    return True
validateK(Xs,Ks)
# Out:
# True

# %%
def plot_XKhelices(helices,Xs,Ks):
    figure(figsize=(12,4))
    hold(True)
    for i,data in helices.iteritems():
        plot([0,length],[i,i],color="b")
        idx = np.nonzero(data !=-1)[0]
        y = data[idx]
        plot(idx,y,'o',color="grey",alpha=0.5)
        
        for ii,d in enumerate(y):
            annotate('%d'%d,[idx[ii],i])
        
        Xdata = Xs[i]
        Xidx = np.nonzero(Xdata)[0] # <-- list of indices where crossovers happen!
        for Xi in Xidx:
            plot([Xi,Xi],[i,data[Xi]])
        
        Kdata = Ks[i]
        Kidx = np.nonzero(Kdata)[0]
        Ky = ones(len(Kidx))*i
        plot(Kidx,Ky,'x',color="black")
        
    axis([-2,length,-1,6])
    yticks(range(6))
    xticks(range(0,length,7))
    
plot_XKhelices(helices,Xs,Ks)

# %% [markdown]
# We have way too many kinks! The staples are too short. We need to validate kinks better

# %%
def validateK(Xs,Ks):
    for helix, data in Xs.iteritems():
        if -1 in data[Ks[helix]]:
            raise Exception("Invalid!")
        kidx = np.nonzero(Ks[helix])
        kdist = np.diff
    return True
validateK(Xs,Ks)
